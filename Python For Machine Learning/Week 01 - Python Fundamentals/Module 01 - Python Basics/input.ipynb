# %%
name = input("What is your name?")
print(name)
# Out:
# Nishad Khan

# %%
age = input("Age?")
print(age, type(age))
# Out:
# 32 <class 'str'>

# %%
age = input("Age?") # string
age = int(age) # int
print(age, type(age))
# Out:
# 32 <class 'int'>

# %%
height = float(input("Height?"))
height = height + 0.2
print(height, type(height))
# Out:
# 7.0 <class 'float'>
